# %%
# !pip install -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt
# Out:
# Collecting anyio==4.0.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 1))
#   Downloading anyio-4.0.0-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 2.1 MB/s eta 0:00:00
# Collecting backoff==2.2.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 2))
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting bcrypt==4.0.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 3))
#   Downloading bcrypt-4.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.7/593.7 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi==2023.7.22 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 4)) (2023.7.22)
# Collecting charset-normalizer==3.2.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 5))
#   Downloading charset_normalizer-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.8/201.8 kB 26.8 MB/s eta 0:00:00
# Collecting chroma-hnswlib==0.7.3 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 6))
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 58.7 MB/s eta 0:00:00
# Collecting chromadb==0.4.10 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 7))
#   Downloading chromadb-0.4.10-py3-none-any.whl (422 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.4/422.4 kB 42.8 MB/s eta 0:00:00
# Requirement already satisfied: click==8.1.7 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 8)) (8.1.7)
# Collecting colorama==0.4.6 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 9))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting coloredlogs==15.0.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 10))
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: contourpy==1.1.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 11)) (1.1.1)
# Collecting cycler==0.11.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 12))
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: exceptiongroup==1.1.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 13)) (1.1.3)
# Collecting fastapi==0.99.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 14))
#   Downloading fastapi-0.99.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock==3.12.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 15)) (3.12.4)
# Requirement already satisfied: flatbuffers==23.5.26 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 16)) (23.5.26)
# Collecting fonttools==4.42.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 17))
#   Downloading fonttools-4.42.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 97.8 MB/s eta 0:00:00
# Collecting fsspec==2023.9.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 18))
#   Downloading fsspec-2023.9.1-py3-none-any.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.4/173.4 kB 21.1 MB/s eta 0:00:00
# Collecting h11==0.14.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 19))
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00
# Collecting httptools==0.6.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 20))
#   Downloading httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.8/428.8 kB 41.9 MB/s eta 0:00:00
# Collecting huggingface-hub==0.16.4 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 21))
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 34.0 MB/s eta 0:00:00
# Collecting humanfriendly==10.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 22))
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: idna==3.4 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 23)) (3.4)
# Collecting importlib-resources==6.0.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 24))
#   Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: joblib==1.3.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 25)) (1.3.2)
# Requirement already satisfied: kiwisolver==1.4.5 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 26)) (1.4.5)
# Collecting matplotlib==3.8.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 27))
#   Downloading matplotlib-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 107.5 MB/s eta 0:00:00
# Collecting monotonic==1.6 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 28))
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 29)) (1.3.0)
# Collecting numpy==1.26.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 30))
#   Downloading numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 88.2 MB/s eta 0:00:00
# Collecting onnxruntime==1.15.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 31))
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 105.3 MB/s eta 0:00:00
# Collecting overrides==7.4.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 32))
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Collecting packaging==23.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 33))
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 6.3 MB/s eta 0:00:00
# Collecting pandas==2.1.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 34))
#   Downloading pandas-2.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 97.5 MB/s eta 0:00:00
# Collecting Pillow==10.0.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 35))
#   Downloading Pillow-10.0.1-cp310-cp310-manylinux_2_28_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 114.1 MB/s eta 0:00:00
# Collecting posthog==3.0.2 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 36))
#   Downloading posthog-3.0.2-py2.py3-none-any.whl (37 kB)
# Collecting protobuf==4.24.3 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 37))
#   Downloading protobuf-4.24.3-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.6/311.6 kB 31.6 MB/s eta 0:00:00
# Collecting pulsar-client==3.3.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 38))
#   Downloading pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 92.3 MB/s eta 0:00:00
# Collecting pydantic==1.10.12 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 39))
#   Downloading pydantic-1.10.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing==3.1.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 40)) (3.1.1)
# Collecting PyPika==0.48.9 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 41))
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 8.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pyreadline3==3.4.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 42))
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 13.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 43)) (2.8.2)
# Collecting python-dotenv==1.0.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 44))
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pytz==2023.3.post1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 45)) (2023.3.post1)
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 46)) (6.0.1)
# Requirement already satisfied: requests==2.31.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 47)) (2.31.0)
# Collecting scikit-learn==1.3.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 48))
#   Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 90.3 MB/s eta 0:00:00
# Collecting scipy==1.11.2 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 49))
#   Downloading scipy-1.11.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.3/36.3 MB 36.0 MB/s eta 0:00:00
# Requirement already satisfied: six==1.16.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 50)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 51)) (1.3.0)
# Collecting starlette==0.27.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 52))
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: sympy==1.12 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 53)) (1.12)
# Requirement already satisfied: threadpoolctl==3.2.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 54)) (3.2.0)
# Collecting tokenizers==0.14.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 55))
#   Downloading tokenizers-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 100.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm==4.66.1 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 56)) (4.66.1)
# Collecting typing_extensions==4.7.1 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 57))
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting tzdata==2023.3 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 58))
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 31.7 MB/s eta 0:00:00
# Collecting urllib3==2.0.4 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 59))
#   Downloading urllib3-2.0.4-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 15.6 MB/s eta 0:00:00
# Collecting uvicorn==0.23.2 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 60))
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 8.4 MB/s eta 0:00:00
# Collecting watchfiles==0.20.0 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 61))
#   Downloading watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.5 MB/s eta 0:00:00
# Collecting websockets==11.0.3 (from -r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 62))
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.0 MB/s eta 0:00:00
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn==0.23.2->-r /content/drive/MyDrive/Aprendizaje/Practica3/requirements.txt (line 60))
#   Downloading uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 110.5 MB/s eta 0:00:00
# Building wheels for collected packages: PyPika
#   Building wheel for PyPika (pyproject.toml) ... done
#   Created wheel for PyPika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=738a26ad15448112bd86481259d9cab09b580199742b82b26f378199be04287b
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built PyPika
# Installing collected packages: pyreadline3, PyPika, monotonic, websockets, uvloop, urllib3, tzdata, typing_extensions, python-dotenv, pulsar-client, protobuf, Pillow, packaging, overrides, numpy, importlib-resources, humanfriendly, httptools, h11, fsspec, fonttools, cycler, colorama, charset-normalizer, bcrypt, backoff, anyio, watchfiles, uvicorn, starlette, scipy, pydantic, pandas, coloredlogs, chroma-hnswlib, scikit-learn, posthog, onnxruntime, matplotlib, huggingface-hub, fastapi, tokenizers, chromadb
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.6
#     Uninstalling urllib3-2.0.6:
#       Successfully uninstalled urllib3-2.0.6
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Uninstalling packaging-23.2:
#       Successfully uninstalled packaging-23.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: importlib-resources
#     Found existing installation: importlib-resources 6.1.0
#     Uninstalling importlib-resources-6.1.0:
#       Successfully uninstalled importlib-resources-6.1.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Uninstalling fsspec-2023.6.0:
#       Successfully uninstalled fsspec-2023.6.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.43.1
#     Uninstalling fonttools-4.43.1:
#       Successfully uninstalled fonttools-4.43.1
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.0
#     Uninstalling charset-normalizer-3.3.0:
#       Successfully uninstalled charset-normalizer-3.3.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.3
#     Uninstalling scipy-1.11.3:
#       Successfully uninstalled scipy-1.11.3
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.13
#     Uninstalling pydantic-1.10.13:
#       Successfully uninstalled pydantic-1.10.13
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cupy-cuda11x 11.0.0 requires numpy<1.26,>=1.20, but you have numpy 1.26.0 which is incompatible.
# gcsfs 2023.6.0 requires fsspec==2023.6.0, but you have fsspec 2023.9.1 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.1.0 which is incompatible.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.0.0 which is incompatible.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 1.26.0 which is incompatible.
# tensorflow 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.26.0 which is incompatible.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.7.1 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 4.24.3 which is incompatible.
# Successfully installed Pillow-10.0.1 PyPika-0.48.9 anyio-4.0.0 backoff-2.2.1 bcrypt-4.0.1 charset-normalizer-3.2.0 chroma-hnswlib-0.7.3 chromadb-0.4.10 colorama-0.4.6 coloredlogs-15.0.1 cycler-0.11.0 fastapi-0.99.1 fonttools-4.42.1 fsspec-2023.9.1 h11-0.14.0 httptools-0.6.0 huggingface-hub-0.16.4 humanfriendly-10.0 importlib-resources-6.0.1 matplotlib-3.8.0 monotonic-1.6 numpy-1.26.0 onnxruntime-1.15.1 overrides-7.4.0 packaging-23.1 pandas-2.1.0 posthog-3.0.2 protobuf-4.24.3 pulsar-client-3.3.0 pydantic-1.10.12 pyreadline3-3.4.1 python-dotenv-1.0.0 scikit-learn-1.3.0 scipy-1.11.2 starlette-0.27.0 tokenizers-0.14.0 typing_extensions-4.7.1 tzdata-2023.3 urllib3-2.0.4 uvicorn-0.23.2 uvloop-0.17.0 watchfiles-0.20.0 websockets-11.0.3

# %%
import os
import requests
import pandas as pd
import numpy as np

# hugging face token
os.environ['hf_token'] = os.environ.get('HF_TOKEN')
# os.environ['hf_token'] = 'testtoken123'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-9f5f362ee47e> in <cell line: 7>()
#       5
#       6 # hugging face token
# ----> 7 os.environ['hf_token'] = os.environ.get('HF_TOKEN')
#       8 # os.environ['hf_token'] = 'testtoken123'
#
# /usr/lib/python3.10/os.py in __setitem__(self, key, value)
#     683     def __setitem__(self, key, value):
#     684         key = self.encodekey(key)
# --> 685         value = self.encodevalue(value)
#     686         putenv(key, value)
#     687         self._data[key] = value
#
# /usr/lib/python3.10/os.py in encode(value)
#     755         def encode(value):
#     756             if not isinstance(value, str):
# --> 757                 raise TypeError("str expected, not %s" % type(value).__name__)
#     758             return value.encode(encoding, 'surrogateescape')
#     759         def decode(value):
#
# TypeError: str expected, not NoneType

# %%
os.getenv('HF_TOKEN', "not found")
# Out:
# 'not found'

# %%
text_chunks = [
    "The sky is blue.",
    "The grass is green.",
    "The sun is shining.",
    "I love chocolate.",
    "Pizza is delicious.",
    "Coding is fun.",
    "Roses are red.",
    "Violets are blue.",
    "Water is essential for life.",
    "The moon orbits the Earth.",
]

# %%
def _get_embeddings(text_chunk):
    '''
    Use embedding model from hugging face to calculate embeddings for the text snippets provided

    Parameters:
        - text_chunk (string): the sentence or text snippet you want to translate into embeddings

    Returns:
        - embedding(list): list with all embedding dimensions
    '''
    # define the embedding model you want to use
    model_id = "sentence-transformers/all-MiniLM-L6-v2"

    # you can find the token to the hugging face api in your settings page https://huggingface.co/settings/tokens
    hf_token = os.environ.get('hf_token')

    # API endpoint for embedding model
    api_url = f"https://api-inference.huggingface.co/pipeline/feature-extraction/{model_id}"
    headers = {"Authorization": f"Bearer {hf_token}"}

    # call API
    response = requests.post(api_url, headers=headers, json={"inputs": text_chunk, "options":{"wait_for_model":True}})

    # load response from embedding model into json format
    embedding = response.json()

    return embedding

# %%
def from_text_to_embeddings(text_chunks):
    '''
    Translate sentences into vector embeddings

    Attributes:
        - text_chunks (list): list of example strings

    Returns:
        - embeddings_df (DataFrame): data frame with the columns "text_chunk" and "embeddings"
    '''
    # create new data frame using text chunks list
    embeddings_df = pd.DataFrame(text_chunks).rename(columns={0:"text_chunk"})

    # use the _get_embeddings function to retrieve the embeddings for each of the sentences
    embeddings_df["embeddings"] = embeddings_df["text_chunk"].apply(_get_embeddings)

    # split the embeddings column into individuell columns for each vector dimension
    embeddings_df = embeddings_df['embeddings'].apply(pd.Series)
    embeddings_df["text_chunk"] = text_chunks

    return embeddings_df

# %%
# get embeddings for each of the text chunks
embeddings_df = from_text_to_embeddings(text_chunks)

# save data frame with text chunks and embeddings to csv
embeddings_df.to_csv('/content/drive/MyDrive/Aprendizaje/Practica3/embeddings_df1.csv', index=False)

# %%
embeddings_df
# Out:
#                                                error  \
# 0  Authorization header is correct, but the token...
# 1  Authorization header is correct, but the token...
# 2  Authorization header is correct, but the token...
# 3  Authorization header is correct, but the token...
# 4  Authorization header is correct, but the token...
# 5  Authorization header is correct, but the token...
# 6  Authorization header is correct, but the token...
# 7  Authorization header is correct, but the token...
# 8  Authorization header is correct, but the token...
# 9  Authorization header is correct, but the token...
#
#                      text_chunk
# 0              The sky is blue.
# 1           The grass is green.
# 2           The sun is shining.
# 3             I love chocolate.
# 4           Pizza is delicious.
# 5                Coding is fun.
# 6                Roses are red.
# 7             Violets are blue.
# 8  Water is essential for life.
# 9    The moon orbits the Earth.
